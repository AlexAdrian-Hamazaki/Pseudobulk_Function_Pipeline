# %%
import pandas as pd

# %%
annot_df = pd.read_csv("")

# %%
pc_map = pd.read_csv("/space/grp/aadrian/Pseudobulk_Function_Pipeline_HighRes/bin/preprocessing/preprocessGenes_pipe/data/genes/humanAllGenes.csv", sep = ",", header = 0)
pc_map
# Out:
#        ensembl_gene_id hgnc_symbol uniprotswissprot  entrezgene_id  \
# 0      ENSG00000198888      MT-ND1           P03886         4535.0
# 1      ENSG00000198763      MT-ND2           P03891         4536.0
# 2      ENSG00000198804      MT-CO1           P00395         4512.0
# 3      ENSG00000198712      MT-CO2           P00403         4513.0
# 4      ENSG00000228253     MT-ATP8           P03928         4509.0
# ...                ...         ...              ...            ...
# 39591  ENSG00000197312        DDI2              NaN        84301.0
# 39592  ENSG00000197312        DDI2           Q5TDH0        84301.0
# 39593  ENSG00000215695      RSC1A1           Q92681         6248.0
# 39594  ENSG00000116786     PLEKHM2           Q8IWE5        23207.0
# 39595  ENSG00000116786     PLEKHM2              NaN        23207.0
#
#                                              description
# 0      mitochondrially encoded NADH:ubiquinone oxidor...
# ...

# %%
pc_map
# Out:
#        ensembl_gene_id hgnc_symbol uniprotswissprot  entrezgene_id  \
# 0      ENSG00000198888      MT-ND1           P03886         4535.0
# 1      ENSG00000198763      MT-ND2           P03891         4536.0
# 2      ENSG00000198804      MT-CO1           P00395         4512.0
# 3      ENSG00000198712      MT-CO2           P00403         4513.0
# 4      ENSG00000228253     MT-ATP8           P03928         4509.0
# ...                ...         ...              ...            ...
# 39591  ENSG00000197312        DDI2              NaN        84301.0
# 39592  ENSG00000197312        DDI2           Q5TDH0        84301.0
# 39593  ENSG00000215695      RSC1A1           Q92681         6248.0
# 39594  ENSG00000116786     PLEKHM2           Q8IWE5        23207.0
# 39595  ENSG00000116786     PLEKHM2              NaN        23207.0
#
#                                              description
# 0      mitochondrially encoded NADH:ubiquinone oxidor...
# ...
