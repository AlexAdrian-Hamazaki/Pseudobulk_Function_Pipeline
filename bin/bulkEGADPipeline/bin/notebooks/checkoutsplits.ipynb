# %%
import pandas as pd

# %%
df = pd.read_csv("/space/grp/aadrian/Pseudobulk_Function_Pipeline_HighRes/bin/bulkEGADPipeline/data/splitOPs1/splits/Blood_split.csv.gz", index_col = 0)
df.head()
# Out:
#                           OR4F5  OR4F29  OR4F16  SAMD11   NOC2L  KLHL17  \
# SAMPID
# GTEX-111YS-0006-SM-5NQBE    0.0     0.0     0.0     2.0  1200.0   184.0
# GTEX-1122O-0003-SM-5Q5DL    1.0     0.0     0.0     2.0  8134.0   919.0
# GTEX-1122O-0005-SM-5O99J    1.0     0.0     0.0     3.0   674.0   117.0
# GTEX-1128S-0005-SM-5P9HI    0.0     0.0     0.0     2.0  1498.0   742.0
# GTEX-113IC-0006-SM-5NQ9C    0.0     0.0     0.0     4.0  1869.0   584.0
#
#                           PLEKHN1  PERM1   HES4    ISG15  ...    MT-CO2  \
# SAMPID                                                    ...
# GTEX-111YS-0006-SM-5NQBE     27.0   13.0   10.0    447.0  ...  135021.0
# GTEX-1122O-0003-SM-5Q5DL    139.0   33.0  354.0  35795.0  ...  630739.0
# GTEX-1122O-0005-SM-5O99J      9.0    7.0   36.0    482.0  ...   65060.0
# GTEX-1128S-0005-SM-5P9HI    119.0   37.0   60.0    392.0  ...  106654.0
# GTEX-113IC-0006-SM-5NQ9C    150.0   50.0  456.0  10134.0  ...   49286.0
#
# ...

# %%
df1 = pd.read_csv("/space/grp/aadrian/Pseudobulk_Function_Pipeline_HighRes/bin/bulkEGADPipeline/data/splitOPs1/splits/subsamples/Blood_split.csv_1.csv.gz")
df1
# Out:
#     Unnamed: 0                    SAMPID  OR4F5  OR4F29  OR4F16  SAMD11  \
# 0          163  GTEX-14BMU-0006-SM-5MR3T    0.0     0.0     1.0     2.0
# 1          473  GTEX-1KANB-0006-SM-DIPE6    1.0     0.0     1.0     8.0
# 2           33  GTEX-11OC5-0006-SM-5N9FA    1.0     0.0     2.0     7.0
# 3          695   GTEX-U3ZH-0005-SM-3DB72    2.0     0.0     3.0    15.0
# 4          411  GTEX-1I1CD-0005-SM-ADEGY    0.0     0.0     0.0     5.0
# ..         ...                       ...    ...     ...     ...     ...
# 95         508  GTEX-1MUQO-0005-SM-DKPPT    0.0     0.0     0.0     3.0
# 96         198  GTEX-14PKV-0006-SM-9MQL3    0.0     1.0     0.0     6.0
# 97         504  GTEX-1MGNQ-0005-SM-CXZJ1    1.0     0.0     0.0     2.0
# 98         903   GTEX-ZTSS-0004-SM-4YCCS    0.0     1.0     1.0    13.0
# 99         432  GTEX-1IDJI-0006-SM-CMKFJ    0.0     0.0     0.0     3.0
#
#      NOC2L  KLHL17  PLEKHN1  PERM1  ...    MT-CO2  MT-ATP8   MT-ATP6  \
# ...
