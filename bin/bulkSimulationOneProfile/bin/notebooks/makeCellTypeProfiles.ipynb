# %%
import sys
import anndata as ad
import pandas as pd

# %%
adata = ad.read_h5ad("/space/grp/aadrian/Pseudobulk_Function_Pipeline_HighRes/bin/preprocessing/preprocessSC_pipe/data/h5ad_datasets/processed/pc/pbmc_sc_with_metadata_cpm_pc.h5ad")

# %%
adata_grouped = adata.obs.groupby(["Cell type"])
adata_grouped

# %%
adata.obs.loc[:,"Cell type"].unique()
# Out:
# ['Macrophages', 'T-cells', 'Monocytes', 'Nk-cells', 'Platelets', 'Dendritic cells', 'B-cells']
# Categories (7, object): ['B-cells', 'Dendritic cells', 'Macrophages', 'Monocytes', 'Nk-cells', 'Platelets', 'T-cells']

# %%
groups = adata_grouped.ngroup()
groups
# Out:
# 0       2
# 1       6
# 2       6
# 3       3
# 4       4
#        ..
# 5269    6
# 5270    6
# 5271    0
# 5272    2
# 5273    5
# Length: 5139, dtype: int64

# %%
dictCellTypeProfile = {}

for group, lo_cell_ids in adata_grouped.indices.items():
    
    # Retrive all the cells in a cell type
    grouped_cells = adata[lo_cell_ids,:]
    
    # Summarize the counts for that cell type
    cell_type_profile = grouped_cells.X.mean(axis = 0)
    
    # Add to the dict. key will be the cell type(group) and the value would be a list of summarized genes
    dictCellTypeProfile[group] = cell_type_profile

# %%
pd.DataFrame(dictCellTypeProfile).T
# Out:
#                    0          1          2         3           4      \
# B-cells          0.00000  45.428104  11.778991  0.000000   30.274693
# Dendritic cells  0.00000  68.408936  36.805954  0.000000   12.553323
# Macrophages      0.00000  43.924252   5.971307  1.161990  291.026764
# Monocytes        0.00000  39.946606   5.039212  1.032825  203.944977
# Nk-cells         0.00000  49.100941  18.632038  0.000000  262.906281
# Platelets        0.00000  16.763615   0.000000  0.000000    0.000000
# T-cells          0.35938  43.052025  10.715339  1.873682   24.191853
#
#                     5          6          7          8         9      ...  \
# B-cells          0.000000   6.640384   5.204200   5.037246  1.505661  ...
# Dendritic cells  0.000000   0.000000   4.085568  19.471066  0.000000  ...
# Macrophages      0.413516  46.003769  12.766613   9.777378  0.996878  ...
# Monocytes        0.478578  36.379482  10.753378   4.827321  0.449795  ...
# Nk-cells         0.000000  12.905994  17.421053   8.500007  0.000000  ...
# Platelets        0.000000  26.499451   0.000000   0.000000  0.000000  ...
# T-cells          2.288881   5.040259   7.344766   6.696029  3.011085  ...
#
#                     13429     13430     13431     13432      13433     13434  \
# B-cells          0.000000  0.000000  0.000000  4.356389   3.965909  0.000000
# Dendritic cells  0.000000  0.000000  0.000000  0.000000  17.795952  0.000000
# Macrophages      0.647243  1.023854  1.424591  0.230342  10.056190  0.000000
# Monocytes        0.611022  0.467602  3.725113  0.593051  13.046303  0.000000
# Nk-cells         1.368982  0.000000  0.000000  2.171576   0.969782  0.000000
# Platelets        0.000000  0.000000  0.000000  0.000000   0.000000  0.000000
# T-cells          0.065097  0.111254  0.258002  0.557031   3.786745  0.266327
#
#                     13435     13436     13437     13438
# B-cells          3.077271  0.000000  1.462741  0.000000
# Dendritic cells  0.000000  0.000000  0.000000  3.935087
# Macrophages      2.415708  0.172450  0.000000  0.166218
# Monocytes        1.470067  0.000000  0.448083  1.223888
# Nk-cells         1.123621  0.000000  0.821828  0.872440
# Platelets        0.000000  0.000000  0.000000  0.000000
# T-cells          1.536254  0.373038  1.396250  0.609246
#
# [7 rows x 13439 columns]
