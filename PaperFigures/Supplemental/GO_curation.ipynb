# %%
import pandas as pd

# %%
df = pd.read_csv("/space/grp/aadrian/Pseudobulk_Function_Pipeline_HighRes/bin/preprocessing/preprocessGO_pipe/data/2024_march/data/GOCurations.tsv", sep = "\t")

# %%
def create_new_column(df):
    """
    Create a new column based on conditions in existing columns.

    Parameters:
    - df: pandas DataFrame

    Returns:
    - pandas DataFrame with a new column "NewColumn"
    """
    # Create a new column using conditions
    meta = df.apply(lambda row: 'Brain' if row['BrainAffiliated'] == 'T' else ('PBMC' if row['PBMCAffiliated'] == 'T' else "Neither"), axis=1)

    return meta
df['meta'] = create_new_column(df)

# %%
df.value_counts("meta")
# Out:
# meta
# Neither    1187
# PBMC        110
# Brain        99
# Name: count, dtype: int64
